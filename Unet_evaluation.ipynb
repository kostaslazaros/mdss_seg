# %%
import sys
sys.path.append('./')
from segmentation_functions import unet_eval as une

# %%
unet = une.get_pretrained_model("pretrained_models/best_unet.h5")

# %%
unet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 288, 384, 3  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 288, 384, 16  448         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 288, 384, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 288, 384, 16  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 288, 384, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 288, 384, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
# ...

# %%
test_x, test_y, test_dataset, test_steps = une.get_data("cvc_ready")

# %%
une.evaluate_normal(unet, test_x, test_y, "Unet_results")
# Out:
# 100%|██████████████████████████████████████████| 61/61 [00:13<00:00,  4.56it/s]

# %%
unet.evaluate(test_dataset, steps=test_steps)
# Out:
# 8/8 [==============================] - 4s 196ms/step - loss: 1106.3473 - acc: 0.7852 - recall_2: 0.0856 - precision_2: 0.0588 - iou: 0.0902
# [1106.3472900390625,
#  0.7851638197898865,
#  0.08563507348299026,
#  0.05884875729680061,
#  0.09023116528987885]
