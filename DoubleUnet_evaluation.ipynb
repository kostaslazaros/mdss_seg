# %%
import sys
sys.path.append('./')
from segmentation_functions import doubleUnet_eval as wne

# %%
wnet = wne.load_wnet_model_weights("pretrained_models/CVC-612model.h5")

# %%
wnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 288, 384, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 288, 384, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 288, 384, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 144, 192, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 144, 192, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 144, 192, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
# ...

# %%
test_x, test_y, test_dataset, test_steps = wne.get_data("cvc_ready", batch_size=8)

# %%
wnet.evaluate(test_dataset, steps=test_steps)
# Out:
# 8/8 [==============================] - 18s 794ms/step - loss: 0.0059 - dice_coef: 0.9828 - iou: 0.9662 - recall: 0.9274 - precision: 0.9936
# [0.00593030359596014,
#  0.9827803373336792,
#  0.9661974906921387,
#  0.9273971319198608,
#  0.993607759475708]

# %%
wne.evaluate_doubleu(wnet, test_x, test_y, 'DoubleUnet_results')
# Out:
# 100%|██████████████████████████████████████████| 61/61 [00:25<00:00,  2.35it/s]
